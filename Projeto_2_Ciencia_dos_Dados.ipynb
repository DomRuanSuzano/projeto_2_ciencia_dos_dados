# %% [markdown]
# ### GRUPO : DOM RUAN SUZANO, GRASIELLY ALMEIDA, HUDSON MONTEIRO, QUÉZIA MOURA

# %%
# lendo a base de dados
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DOHMH_HIV_AIDS_Annual_Report.csv')
df
# Out:
#       Year        Borough          UHF       Gender      Age  \
# 0     2011            All          All          All      All
# 1     2011            All          All         Male      All
# 2     2011            All          All       Female      All
# 3     2011            All          All  Transgender      All
# 4     2011            All          All       Female  13 - 19
# ...    ...            ...          ...          ...      ...
# 6000  2015  Staten Island  Willowbrook         Male      All
# 6001  2015  Staten Island  Willowbrook         Male      All
# 6002  2015  Staten Island  Willowbrook         Male      All
# 6003  2015  Staten Island  Willowbrook         Male      All
# 6004  2015  Staten Island  Willowbrook         Male      All
#
#                         Race  HIV diagnoses  HIV diagnosis rate  \
# 0                        All           3379                48.3
# 1                        All           2595                79.1
# 2                        All            733                21.1
# 3                        All             51             99999.0
# 4                        All             47                13.6
# ...                      ...            ...                 ...
# 6000  Asian/Pacific Islander              0                 0.0
# 6001                   Black              1                72.4
# 6002         Latino/Hispanic              2                43.9
# 6003           Other/Unknown              1               218.9
# 6004                   White              0                 0.0
#
#       Concurrent diagnoses  % linked to care within 3 months  AIDS diagnoses  \
# 0                      640                                66            2366
# 1                      480                                66            1712
# 2                      153                                66             622
# 3                        7                                63              32
# 4                        4                                64              22
# ...                    ...                               ...             ...
# 6000                     0                             99999               0
# 6001                     0                               100               0
# 6002                     0                               100               0
# 6003                     0                                 0               0
# 6004                     0                             99999               0
#
#       AIDS diagnosis rate  PLWDHI prevalence  % viral suppression  Deaths  \
# 0                    33.8                1.1                   71    2040
# 1                    52.2                1.7                   72    1423
# 2                    17.6                0.6                   68     605
# 3                 99999.0            99999.0                   55      12
# 4                     6.4                0.1                   57       1
# ...                   ...                ...                  ...     ...
# 6000                  0.0                0.1                  100       0
# 6001                  0.0                1.1                   80       0
# 6002                  0.0                0.7                   87       1
# 6003                  0.0                0.7                  100       0
# 6004                  0.0                0.2                   93       0
#
#       Death rate  HIV-related death rate  Non-HIV-related death rate
# 0           13.6                     5.8                         7.8
# 1           13.4                     5.7                         7.7
# 2           14.0                     6.0                         8.0
# 3           11.1                     5.7                         5.4
# 4            1.4                     1.4                         0.0
# ...          ...                     ...                         ...
# 6000         0.0                 99999.0                     99999.0
# 6001         0.0                 99999.0                     99999.0
# 6002         8.3                 99999.0                     99999.0
# 6003         0.0                 99999.0                     99999.0
# 6004         0.0                 99999.0                     99999.0
#
# [6005 rows x 18 columns]

# %%
set(list(df['Gender']))
# Out:
# {'All', 'Female', 'Male', 'Transgender'}

# %%
# limpando o gênero All e Transgender 
limpa_all = df['Gender'] != 'All'
limpa_trans = df['Gender'] != 'Transgender'
new_df = df.loc[limpa_all,:]
base = new_df.loc[limpa_trans,:]

# %%
base = base.drop(['% viral suppression','Borough','UHF','Race','PLWDHI prevalence','Concurrent diagnoses','% linked to care within 3 months','Borough'], axis = 1)
base
# Out:
#       Year  Gender      Age  HIV diagnoses  HIV diagnosis rate  \
# 1     2011    Male      All           2595                79.1
# 2     2011  Female      All            733                21.1
# 4     2011  Female  13 - 19             47                13.6
# 5     2011  Female  20 - 29            178                24.7
# 6     2011  Female  30 - 39            176                26.9
# ...    ...     ...      ...            ...                 ...
# 6000  2015    Male      All              0                 0.0
# 6001  2015    Male      All              1                72.4
# 6002  2015    Male      All              2                43.9
# 6003  2015    Male      All              1               218.9
# 6004  2015    Male      All              0                 0.0
#
#       AIDS diagnoses  AIDS diagnosis rate  Deaths  Death rate  \
# 1               1712                 52.2    1423        13.4
# 2                622                 17.6     605        14.0
# 4                 22                  6.4       1         1.4
# 5                 96                 13.3      19         7.2
# 6                133                 20.3      53         9.4
# ...              ...                  ...     ...         ...
# 6000               0                  0.0       0         0.0
# 6001               0                  0.0       0         0.0
# 6002               0                  0.0       1         8.3
# 6003               0                  0.0       0         0.0
# 6004               0                  0.0       0         0.0
#
#       HIV-related death rate  Non-HIV-related death rate
# 1                        5.7                         7.7
# 2                        6.0                         8.0
# 4                        1.4                         0.0
# 5                        3.2                         4.0
# 6                        5.7                         3.7
# ...                      ...                         ...
# 6000                 99999.0                     99999.0
# 6001                 99999.0                     99999.0
# 6002                 99999.0                     99999.0
# 6003                 99999.0                     99999.0
# 6004                 99999.0                     99999.0
#
# [5760 rows x 11 columns]
